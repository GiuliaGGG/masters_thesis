# %%
#pip install edgartools
#pip install ipywidget
#pip install -U sec-edgar-downloader
# !pip install -U sec-edgar-downloader
# Out:
# Collecting sec-edgar-downloader
#   Using cached sec_edgar_downloader-5.0.3-py3-none-any.whl.metadata (11 kB)
# Collecting requests (from sec-edgar-downloader)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pyrate-limiter>=3.6.0 in /Users/gpetrilli/miniconda3/envs/myenv/lib/python3.11/site-packages (from sec-edgar-downloader) (3.9.0)
# Collecting charset_normalizer<4,>=2 (from requests->sec-edgar-downloader)
#   Downloading charset_normalizer-3.4.3-cp311-cp311-macosx_10_9_universal2.whl.metadata (36 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gpetrilli/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests->sec-edgar-downloader) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests->sec-edgar-downloader)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gpetrilli/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests->sec-edgar-downloader) (2024.12.14)
# Using cached sec_edgar_downloader-5.0.3-py3-none-any.whl (14 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 8.4 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.3-cp311-cp311-macosx_10_9_universal2.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.5/204.5 kB 5.4 MB/s eta 0:00:00
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 16.7 MB/s eta 0:00:00
# Installing collected packages: urllib3, charset_normalizer, requests, sec-edgar-downloader
# Successfully installed charset_normalizer-3.4.3 requests-2.32.5 sec-edgar-downloader-5.0.3 urllib3-2.5.0

# %%
from edgar import set_identity

set_identity("Giulia Petrilli giuliapetrilli2000@gmail.com")

# %%
from edgar import Company

cocacola = Company("COKE")
cocacola
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────── 🏢 Coca-Cola Consolidated, Inc. COKE ──────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │ ╭───────────────────────────────────────────────── 📋 Entity ─────────────────────────────────────────────────╮ │
# │ │                                                                                                             │ │
# │ │   CIK   317540   Type   Operating   ○                                                                       │ │
# │ │                                                                                                             │ │
# │ │                                                                                                             │ │
# │ │   Category                  Industry                                                 Fiscal Year End        │ │
# │ │  ────────────────────────────────────────────────────────────────────────────────────────────────────       │ │
# │ │   Large accelerated filer   2086: Bottled & Canned Soft Drinks & Carbonated Waters   Dec 31                 │ │
# │ │                                                                                                             │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │ ╭─────────────────────────────────────────────── 📈 Exchanges ────────────────────────────────────────────────╮ │
# │ │                                                                                                             │ │
# │ │   Exchange   Symbol                                                                                         │ │
# │ │  ───────────────────                                                                                        │ │
# │ │   Nasdaq     COKE                                                                                           │ │
# │ │                                                                                                             │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │ ╭── 🏢 Business Address ───╮         ╭─── 📫 Mailing Address ───╮       ╭─ 📞 Contact Information ─╮            │
# │ │ 4100 COCA COLA PLZ       │         │ 4100 COCA COLA PLZ       │       │                          │            │
# │ │ CHARLOTTE, NC 28211      │         │ CHARLOTTE, NC 28211      │       │   Phone   9803928298     │            │
# │ ╰──────────────────────────╯         ╰──────────────────────────╯       │                          │            │
# │                                                                         ╰──────────────────────────╯            │
# │ ╭────────────────────────────────────────────── 📜 Former Names ──────────────────────────────────────────────╮ │
# │ │                                                                                                             │ │
# │ │   COCA COLA BOTTLING CO CONSOLIDATED /DE/   November 1994 to December 2018                                  │ │
# │ │                                                                                                             │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────── SEC Entity Data ────────────────────────────────────────────────╯

# %%
cocacola.get_financials()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────────── XBRL Document ─────────────────────────────────────────────────╮
# │                     Entity Information                                                                          │
# │                                                                                                                 │
# │   Property                   Value                                                                              │
# │  ─────────────────────────────────────────────────────────                                                      │
# │   entity_name                COCA-COLA CONSOLIDATED, INC.                                                       │
# │   ticker                     COKE                                                                               │
# │   identifier                 317540                                                                             │
# │   document_type              10-K                                                                               │
# │   reporting_end_date         2025-12-31                                                                         │
# │   document_period_end_date   2024-12-31                                                                         │
# │   fiscal_year                2024                                                                               │
# │   fiscal_period              FY                                                                                 │
# │   fiscal_year_end_month      12                                                                                 │
# │   fiscal_year_end_day        31                                                                                 │
# │   annual_report              True                                                                               │
# │   quarterly_report           False                                                                              │
# │   amendment                  False                                                                              │
# │                                                                                                                 │
# │                                              Financial Statements                                               │
# │                                                                                                                 │
# │   Type                             Definition                                                        Elements   │
# │  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   CoverPage                        Cover                                                             42         │
# │   Other                            AuditInformation                                                  4          │
# │   IncomeStatement                  CONSOLIDATEDSTATEMENTSOFOPERATIONS                                25         │
# │   ComprehensiveIncome              CONSOLIDATEDSTATEMENTSOFCOMPREHENSIVEINCOME                       13         │
# │   BalanceSheet                     CONSOLIDATEDBALANCESHEETS                                         63         │
# │   BalanceSheetParenthetical        CONSOLIDATEDBALANCESHEETSParenthetical                            18         │
# │   CashFlowStatement                CONSOLIDATEDSTATEMENTSOFCASHFLOWS                                 36         │
# │   StatementOfEquity                CONSOLIDATEDSTATEMENTSOFCHANGESINSTOCKHOLDERSEQUITY               21         │
# │   StatementOfEquityParenthetical   CONSOLIDATEDSTATEMENTSOFCHANGESINSTOCKHOLDERSEQUITYParenthetic…   9          │
# │   AccountingPolicies               DescriptionofBusinessandSummaryofCriticalAccountingPolicies       2          │
# │   Other                            RelatedPartyTransactions                                          2          │
# │   Other                            RevenueRecognition                                                2          │
# │   SegmentDisclosure                Segments                                                          2          │
# │   Other                            NetIncomePerShare                                                 2          │
# │   Other                            ShortTermInvestments                                              2          │
# │   Other                            Inventories                                                       2          │
# │   Other                            PrepaidExpensesandOtherCurrentAssets                              2          │
# │   Other                            PropertyPlantandEquipmentNet                                      2          │
# │   Other                            Leases                                                            3          │
# │   Other                            DistributionAgreementsNet                                         2          │
# │   Other                            CustomerListsNet                                                  2          │
# │   Other                            SupplyChainFinanceProgram                                         2          │
# │   Other                            OtherAccruedLiabilities                                           2          │
# │   Other                            CommodityDerivativeInstruments                                    2          │
# │   Other                            FairValuesofFinancialInstruments                                  2          │
# │   Other                            IncomeTaxes                                                       2          │
# │   Other                            BenefitPlans                                                      2          │
# │   Other                            OtherLiabilities                                                  2          │
# │   Other                            Debt                                                              2          │
# │   Other                            CommitmentsandContingencies                                       2          │
# │   Other                            RisksandUncertainties                                             2          │
# │   Other                            AccumulatedOtherComprehensiveIncomeLoss                           2          │
# │   Disclosures                      SupplementalDisclosuresofCashFlowInformation                      2          │
# │   Other                            ScheduleIIValuationandQualifyingAccountsandReserves               2          │
# │   AccountingPolicies               DescriptionofBusinessandSummaryofCriticalAccountingPoliciesPol…   27         │
# │   Other                            RelatedPartyTransactionsTables                                    4          │
# │   Other                            RevenueRecognitionTables                                          3          │
# │   SegmentDisclosure                SegmentsTables                                                    2          │
# │   Other                            NetIncomePerShareTables                                           2          │
# │   Other                            ShortTermInvestmentsTables                                        2          │
# │   Other                            InventoriesTables                                                 2          │
# │   Other                            PrepaidExpensesandOtherCurrentAssetsTables                        2          │
# │   Other                            PropertyPlantandEquipmentNetTables                                2          │
# │   Other                            LeasesTables                                                      5          │
# │   Other                            DistributionAgreementsNetTables                                   2          │
# │   Other                            CustomerListsNetTables                                            3          │
# │   Other                            SupplyChainFinanceProgramTables                                   2          │
# │   Other                            OtherAccruedLiabilitiesTables                                     2          │
# │   Other                            CommodityDerivativeInstrumentsTables                              5          │
# │   Other                            FairValuesofFinancialInstrumentsTables                            4          │
# │   Other                            IncomeTaxesTables                                                 5          │
# │   Other                            BenefitPlansTables                                                16         │
# │   Other                            OtherLiabilitiesTables                                            2          │
# │   Other                            DebtTables                                                        3          │
# │   Other                            CommitmentsandContingenciesTables                                 2          │
# │   Other                            RisksandUncertaintiesTables                                       2          │
# │   Other                            AccumulatedOtherComprehensiveIncomeLossTables                     2          │
# │   Disclosures                      SupplementalDisclosuresofCashFlowInformationTables                4          │
# │   AccountingPolicies               DescriptionofBusinessandSummaryofCriticalAccountingPoliciesDet…   47         │
# │   Other                            RelatedPartyTransactionsNarrativeDetails                          60         │
# │   Other                            RelatedPartyTransactionsSummaryofSignificantTransactionsbetwee…   8          │
# │   Other                            RelatedPartyTransactionsSummaryofLiabilitytoEstimatedFairValue…   12         │
# │   Other                            RelatedPartyTransactionsSummaryofRentalPaymentsRelatedtoLeases…   8          │
# │   Other                            RevenueRecognitionNarrativeDetails                                26         │
# │   Other                            RevenueRecognitionDisaggregationofRevenuefromContractswithCust…   12         │
# │   Other                            RevenueRecognitionSummaryofActivityinAllowanceforCreditLossesD…   5          │
# │   SegmentDisclosure                SegmentsAdditionalInformationDetails                              7          │
# │   SegmentDisclosure                SegmentsSummaryofFinancialInformationbySegmentDetails             29         │
# │   Other                            NetIncomePerShareComputationofBasicNetIncomePerShareandDiluted…   25         │
# │   Other                            NetIncomePerShareComputationofBasicNetIncomePerShareandDiluted…   16         │
# │   Other                            ShortTermInvestmentsSummaryofAvailableforSaleDebtSecuritiesDet…   13         │
# │   Other                            ShortTermInvestmentsNarrativeDetails                              4          │
# │   Other                            InventoriesSummaryofInventoriesDetails                            5          │
# │   Other                            PrepaidExpensesandOtherCurrentAssetsSummaryofPrepaidExpensesan…   8          │
# │   Other                            PropertyPlantandEquipmentNetPrincipalCategoriesandEstimatedUse…   22         │
# │   Other                            PropertyPlantandEquipmentNetNarrativeDetail                       2          │
# │   Other                            LeasesSummaryofWeightedAverageRemainingLeaseTermandWeightedAve…   7          │
# │   Other                            LeasesSummaryofBalancesRelatedtoLeasePortfoliowithinConsolidat…   6          │
# │   Other                            LeasesSummaryofFutureMinimumLeasePaymentsForNoncancelableOpera…   25         │
# │   Other                            LeasesSummaryofBalancesRelatedtoLeasePortfoliowithinConsolidat…   8          │
# │   Other                            DistributionAgreementsNetNarrativeDetails                         16         │
# │   Other                            DistributionAgreementsNetComponentsofDistributionAgreementsNet…   9          │
# │   Other                            CustomerListsNetNarrativeDetails                                  11         │
# │   Other                            CustomerListsNetOtherIdentifiableIntangibleAssetsDetails          9          │
# │   Other                            CustomerListsNetScheduleofFiniteLivedIntangibleAssetsFutureAmo…   11         │
# │   Other                            SupplyChainFinanceProgramDetails                                  3          │
# │   Other                            SupplyChainFinanceProgramScheduleofSupplyChainFinanceProgramDe…   4          │
# │   Other                            OtherAccruedLiabilitiesSummaryofOtherAccruedLiabilitiesDetails    9          │
# │   Other                            CommodityDerivativeInstrumentsSummaryofPreTaxChangesinFairValu…   11         │
# │   Other                            CommodityDerivativeInstrumentsSummaryofFairValuesandClassifica…   10         │
# │   Other                            CommodityDerivativeInstrumentsSummaryofOutstandingCommodityDer…   7          │
# │   Other                            FairValuesofFinancialInstrumentsDeferredCompensationPlanCommod…   26         │
# │   Other                            FairValuesofFinancialInstrumentsAdditionalInformationDetails      17         │
# │   Other                            FairValuesofFinancialInstrumentsSummaryofReconciliationofAcqui…   11         │
# │   Other                            IncomeTaxesSignificantComponentsoftheProvisionforIncomeTaxesDe…   10         │
# │   Other                            IncomeTaxesNarrativeDetails                                       13         │
# │   Other                            IncomeTaxesReconciliationofIncomeTaxExpenseatStatutoryFederalR…   19         │
# │   Other                            IncomeTaxesReconciliationofUncertainTaxPositionsExcludingAccru…   6          │
# │   Other                            IncomeTaxesTemporaryDifferencesandCarryforwardsthatComprisedDe…   22         │
# │   Other                            BenefitPlansNarrativeDetails                                      44         │
# │   Other                            BenefitPlansLiabilityUnderExecutiveBenefitPlansDetails            15         │
# │   Other                            BenefitPlansNetPeriodicPensionCostDetails                         16         │
# │   Other                            BenefitPlansChangesinProjectedBenefitObligationDetails            16         │
# │   Other                            BenefitPlansChangeinPlanAssetsDetails                             14         │
# │   Other                            BenefitPlansFundedStatusPensionPlansDetails                       12         │
# │   Other                            BenefitPlansAmountsRecognizedintheConsolidatedBalanceSheetDeta…   9          │
# │   Other                            BenefitPlansSignificantAssumptionsUsedPensionPlansDetails         14         │
# │   Other                            BenefitPlansAnticipatedFuturePensionBenefitPaymentsDetails        15         │
# │   Other                            BenefitPlansWeightedAverageExpectedLongTermRateofReturnDetails    23         │
# │   Other                            BenefitPlansSummaryofPensionPlanAssetsDetails                     16         │
# │   Other                            BenefitPlansReconciliationofBenefitObligationDetails              13         │
# │   Other                            BenefitPlansReconciliationofPlanAssetsFairValueDetails            11         │
# │   Other                            BenefitPlansFundedStatusPostretirementBenefitsDetails             9          │
# │   Other                            BenefitPlansComponentsofNetPeriodicPostretirementBenefitCostDe…   10         │
# │   Other                            BenefitPlansSignificantAssumptionsUsedPostretirementBenefitsDe…   13         │
# │   Other                            BenefitPlansAnticipatedFuturePostretirementBenefitPaymentsDeta…   12         │
# │   Other                            BenefitPlansReconciliationofAmountsinAccumulatedOtherComprehen…   18         │
# │   Other                            BenefitPlansMultiemployerPlansDetails                             7          │
# │   Other                            OtherLiabilitiesSummaryofOtherLiabilitiesDetails                  6          │
# │   Other                            OtherLiabilitiesNarrativeDetails                                  13         │
# │   Other                            DebtSummaryofLongTermDebtDetails                                  32         │
# │   Other                            DebtPrincipalMaturitiesofDebtOutstandingDetails                   8          │
# │   Other                            DebtNarrativeDetails                                              28         │
# │   Other                            CommitmentsandContingenciesNarrativeDetails                       14         │
# │   Other                            CommitmentsandContingenciesSummaryofCompanysPurchasesfromManuf…   8          │
# │   Other                            RisksandUncertaintiesNarrativeDetails                             19         │
# │   Other                            RisksandUncertaintiesSummaryofPercentageofTotalBottleCanSalesV…   17         │
# │   Other                            AccumulatedOtherComprehensiveIncomeLossSummaryofAccumulatedOth…   29         │
# │   Disclosures                      SupplementalDisclosuresofCashFlowInformationSummaryofChangesin…   13         │
# │   Disclosures                      SupplementalDisclosuresofCashFlowInformationNetCashPaymentsRef…   3          │
# │   Disclosures                      SupplementalDisclosuresofCashFlowInformationSignificantNoncash…   5          │
# │   Other                            ScheduleIIValuationandQualifyingAccountsandReservesDetails        12         │
# │   Disclosures                      AwardTimingDisclosure                                             20         │
# │   Disclosures                      ErrCompDisclosure                                                 20         │
# │   Disclosures                      PvpDisclosure                                                     54         │
# │   Other                            InsiderTradingArrangements                                        18         │
# │   Other                            InsiderTradingPoliciesProc                                        3          │
# │                                                                                                                 │
# │      Facts Summary                                                                                              │
# │                                                                                                                 │
# │   Category      Count                                                                                           │
# │  ─────────────────────                                                                                          │
# │   Total Facts   1964                                                                                            │
# │   Contexts      433                                                                                             │
# │   Units         14                                                                                              │
# │   Elements      989                                                                                             │
# │                                                                                                                 │
# │            Reporting Periods                                                                                    │
# │                                                                                                                 │
# │   Type       Period                                                                                             │
# │  ─────────────────────────────────────                                                                          │
# │   Instant    2025-12-31                                                                                         │
# │   Instant    2025-01-24                                                                                         │
# │   Instant    2024-12-31                                                                                         │
# │   Duration   2024-01-01 to 2024-12-31                                                                           │
# │   Duration   2024-10-01 to 2024-12-31                                                                           │
# │   Instant    2024-08-20                                                                                         │
# │   Instant    2024-07-05                                                                                         │
# │   Duration   2024-07-05 to 2024-07-05                                                                           │
# │   Instant    2024-06-28                                                                                         │
# │   Instant    2024-06-18                                                                                         │
# │   Duration   2024-06-18 to 2024-06-18                                                                           │
# │   Instant    2024-06-10                                                                                         │
# │   Duration   2024-06-10 to 2024-06-10                                                                           │
# │   Instant    2024-05-29                                                                                         │
# │   Instant    2024-05-20                                                                                         │
# │   Instant    2024-05-06                                                                                         │
# │   Instant    2023-12-31                                                                                         │
# │   Duration   2023-01-01 to 2023-12-31                                                                           │
# │   Instant    2022-12-31                                                                                         │
# │   Duration   2022-01-01 to 2022-12-31                                                                           │
# │   Instant    2021-12-31                                                                                         │
# │   Instant    2021-07-09                                                                                         │
# │   Instant    2018-12-30                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from edgar import get_filings

# %%
filings = get_filings(year=2024, quarter=1, form="10-Q")

# %%
filings = cocacola.get_filings(form="10-Q")
filings
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────── Filings for Coca-Cola Consolidated, Inc. [317540] ───────────────────────────────╮
# │                                                                                                                 │
# │                                                                              Filing                             │
# │    Form        Description                                                   Date         Accession Number      │
# │  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │    10-Q        Quarterly report for public companies                         2025-07-24   0000317540-25-0000…   │
# │    10-Q        Quarterly report for public companies                         2025-04-30   0000317540-25-0000…   │
# │    10-Q        Quarterly report for public companies                         2024-10-30   0000317540-24-0000…   │
# │    10-Q        Quarterly report for public companies                         2024-07-31   0000317540-24-0000…   │
# │    10-Q        Quarterly report for public companies                         2024-05-06   0000317540-24-0000…   │
# │    10-Q        Quarterly report for public companies                         2023-11-01   0000317540-23-0000…   │
# │    10-Q        Quarterly report for public companies                         2023-08-02   0000317540-23-0000…   │
# │    10-Q        Quarterly report for public companies                         2023-05-03   0000317540-23-0000…   │
# │    10-Q        Quarterly report for public companies                         2022-11-01   0000317540-22-0000…   │
# │    10-Q        Quarterly report for public companies                         2022-08-02   0000317540-22-0000…   │
# │    10-Q        Quarterly report for public companies                         2022-05-03   0000317540-22-0000…   │
# │    10-Q        Quarterly report for public companies                         2021-11-09   0000317540-21-0000…   │
# │    10-Q        Quarterly report for public companies                         2021-08-10   0000317540-21-0000…   │
# │    10-Q        Quarterly report for public companies                         2021-05-11   0000317540-21-0000…   │
# │    10-Q        Quarterly report for public companies                         2020-11-03   0000317540-20-0000…   │
# │    10-Q        Quarterly report for public companies                         2020-08-04   0000317540-20-0000…   │
# │    10-Q        Quarterly report for public companies                         2020-05-05   0000317540-20-0000…   │
# │    10-Q        Quarterly report for public companies                         2019-11-05   0001564590-19-0404…   │
# │    10-Q        Quarterly report for public companies                         2019-08-06   0001564590-19-0293…   │
# │    10-Q        Quarterly report for public companies                         2019-05-08   0001564590-19-0173…   │
# │    10-Q        Quarterly report for public companies                         2018-11-08   0001564590-18-0286…   │
# │    10-Q        Quarterly report for public companies                         2018-08-08   0001564590-18-0205…   │
# │    10-Q        Quarterly report for public companies                         2018-05-09   0001564590-18-0125…   │
# │    10-Q        Quarterly report for public companies                         2017-11-07   0001564590-17-0223…   │
# │    10-Q        Quarterly report for public companies                         2017-08-08   0001564590-17-0165…   │
# │    10-Q        Quarterly report for public companies                         2017-05-11   0001564590-17-0105…   │
# │    10-Q        Quarterly report for public companies                         2016-11-10   0001564590-16-0289…   │
# │    10-Q/A      Quarterly report for public companies                         2016-11-04   0001193125-16-7601…   │
# │    10-Q        Quarterly report for public companies                         2016-08-12   0001564590-16-0241…   │
# │    10-Q        Quarterly report for public companies                         2016-05-13   0001564590-16-0193…   │
# │    10-Q        Quarterly report for public companies                         2015-11-06   0001564590-15-0099…   │
# │    10-Q        Quarterly report for public companies                         2015-08-07   0001564590-15-0066…   │
# │    10-Q/A      Quarterly report for public companies                         2015-08-04   0001193125-15-2750…   │
# │    10-Q        Quarterly report for public companies                         2015-05-08   0001193125-15-1793…   │
# │    10-Q        Quarterly report for public companies                         2014-11-07   0001193125-14-4030…   │
# │    10-Q        Quarterly report for public companies                         2014-08-08   0001193125-14-3030…   │
# │    10-Q        Quarterly report for public companies                         2014-05-09   0001193125-14-1923…   │
# │    10-Q        Quarterly report for public companies                         2013-11-08   0001193125-13-4349…   │
# │    10-Q        Quarterly report for public companies                         2013-08-09   0001193125-13-3290…   │
# │    10-Q        Quarterly report for public companies                         2013-05-10   0001193125-13-2136…   │
# │    10-Q        Quarterly report for public companies                         2012-11-09   0001193125-12-4625…   │
# │    10-Q        Quarterly report for public companies                         2012-08-10   0001193125-12-3493…   │
# │    10-Q        Quarterly report for public companies                         2012-05-11   0001193125-12-2278…   │
# │    10-Q        Quarterly report for public companies                         2011-11-14   0000950123-11-0983…   │
# │    10-Q        Quarterly report for public companies                         2011-08-12   0000950123-11-0767…   │
# │    10-Q        Quarterly report for public companies                         2011-05-12   0000950123-11-0494…   │
# │    10-Q        Quarterly report for public companies                         2010-11-12   0000950123-10-1046…   │
# │    10-Q        Quarterly report for public companies                         2010-08-13   0000950123-10-0772…   │
# │    10-Q        Quarterly report for public companies                         2010-05-13   0000950123-10-0489…   │
# │    10-Q        Quarterly report for public companies                         2009-11-06   0000950123-09-0592…   │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │ Showing 1 to 50 of 98 filings. Page using ← prev() and next() →                                                 │
# ╰─────────────────────────────── Company filings between 1994-05-17 and 2025-07-24 ───────────────────────────────╯

# %%
filings.to_pandas() 
print(filings.to_pandas())
# Out:
#         accession_number filing_date  reportDate        acceptanceDateTime  \
# 0   0000317540-25-000070  2025-07-24  2025-06-27 2025-07-24 20:13:26+00:00
# 1   0000317540-25-000053  2025-04-30  2025-03-28 2025-04-30 20:14:44+00:00
# 2   0000317540-24-000061  2024-10-30  2024-09-27 2024-10-30 20:14:29+00:00
# 3   0000317540-24-000046  2024-07-31  2024-06-28 2024-07-31 20:13:47+00:00
# 4   0000317540-24-000032  2024-05-06  2024-03-29 2024-05-06 20:18:12+00:00
# ..                   ...         ...         ...                       ...
# 93  0000950168-95-000676  1995-08-11  1995-07-02 1995-08-11 04:00:00+00:00
# 94  0000950168-95-000441  1995-05-16  1995-04-02 1995-05-16 04:00:00+00:00
# 95  0000950168-94-000372  1994-11-14  1994-10-02 1994-11-14 05:00:00+00:00
# 96  0000950168-94-000287  1994-08-16  1994-07-03 1994-08-16 04:00:00+00:00
# 97  0000950168-94-000200  1994-05-17  1994-04-03 1994-05-17 04:00:00+00:00
#
#    act  form fileNumber items      size  isXBRL  isInlineXBRL  \
# 0   34  10-Q  000-09286        11649032       1             1
# 1   34  10-Q  000-09286        10000408       1             1
# 2   34  10-Q  000-09286        55987952       1             1
# 3   34  10-Q  000-09286        11423381       1             1
# 4   34  10-Q  000-09286         9414152       1             1
# ..  ..   ...        ...   ...       ...     ...           ...
# 93      10-Q  000-09286          128689       0             0
# 94      10-Q  000-09286          232850       0             0
# 95      10-Q  000-09286           80335       0             0
# 96      10-Q  000-09286          159641       0             0
# 97      10-Q  000-09286           41654       0             0
#
#       primaryDocument                    primaryDocDescription
# 0   coke-20250627.htm                                     10-Q
# 1   coke-20250328.htm                                     10-Q
# 2   coke-20240927.htm                                     10-Q
# 3   coke-20240628.htm                                     10-Q
# 4   coke-20240329.htm                                     10-Q
# ..                ...                                      ...
# 93                                        COCA-COLA 82914 10-Q
# 94                                      COCA-COLA 10-Q 80874.1
# 95                         COCA COLA BOTTLING CO. CONSOLIDATED
# 96                     COCA-COLA BOTTLING COMPANY 10-Q 89848.1
# 97                           COCA-COLA FORM 10-Q 89637 5-17-94
#
# [98 rows x 13 columns]

# %%
latest_10q = filings.latest()

# %%
latest_10q
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭────────── Form 10-Q Coca-Cola Consolidated, Inc. [317540]  ───────────╮
# │                                                                       │
# │   Accession Number       Filing Date   Period of Report   Documents   │
# │  ───────────────────────────────────────────────────────────────────  │
# │   0000317540-25-000070   2025-07-24    2025-06-27         112         │
# │                                                                       │
# │                                                                       │
# ╰──────────────── Quarterly report for public companies ────────────────╯

# %%
tenq = latest_10q.obj()
tenq
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────── Coca-Cola Consolidated, Inc. 10-Q ───────────────────────────────────────╮
# │ Period ending June 27, 2025 filed on July 24, 2025                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# │ 📄                                                                                                              │
# │ ├── PART I                                                                                                      │
# │ │   ├── Item 1  Financial Statements                                                                            │
# │ │   ├── Item 2  Management’s Discussion and Analysis of Financial Condition and Results of Operations (MD&A)    │
# │ │   ├── Item 3  Quantitative and Qualitative Disclosures About Market Risk                                      │
# │ │   └── Item 4  Controls and Procedures                                                                         │
# │ └── PART II                                                                                                     │
# │     ├── Item 1  Legal Proceedings                                                                               │
# │     ├── Item 1A Risk Factors                                                                                    │
# │     ├── Item 2  Unregistered Sales of Equity Securities and Use of Proceeds                                     │
# │     ├── Item 3  Defaults Upon Senior Securities                                                                 │
# │     ├── Item 4  Mine Safety Disclosures                                                                         │
# │     ├── Item 5  Other Information                                                                               │
# │     └── Item 6  Exhibits                                                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# │ ╭─────────────────────────────────────────────── XBRL Document ───────────────────────────────────────────────╮ │
# │ │                     Entity Information                                                                      │ │
# │ │                                                                                                             │ │
# │ │   Property                   Value                                                                          │ │
# │ │  ─────────────────────────────────────────────────────────                                                  │ │
# │ │   entity_name                COCA-COLA CONSOLIDATED, INC.                                                   │ │
# │ │   ticker                     COKE                                                                           │ │
# │ │   identifier                 317540                                                                         │ │
# │ │   document_type              10-Q                                                                           │ │
# │ │   reporting_end_date         2025-07-18                                                                     │ │
# │ │   document_period_end_date   2025-06-27                                                                     │ │
# │ │   fiscal_year                2025                                                                           │ │
# │ │   fiscal_period              Q2                                                                             │ │
# │ │   fiscal_year_end_month      12                                                                             │ │
# │ │   fiscal_year_end_day        31                                                                             │ │
# │ │   annual_report              False                                                                          │ │
# │ │   quarterly_report           True                                                                           │ │
# │ │   amendment                  False                                                                          │ │
# │ │                                                                                                             │ │
# │ │                                            Financial Statements                                             │ │
# │ │                                                                                                             │ │
# │ │   Type                             Definition                                                    Elements   │ │
# │ │  ─────────────────────────────────────────────────────────────────────────────────────────────────────────  │ │
# │ │   CoverPage                        Cover                                                         36         │ │
# │ │   IncomeStatement                  CONDENSEDCONSOLIDATEDSTATEMENTSOFOPERATIONSUnaudited          26         │ │
# │ │   ComprehensiveIncome              CONDENSEDCONSOLIDATEDSTATEMENTSOFCOMPREHENSIVEINCOMEUnaudi…   11         │ │
# │ │   BalanceSheet                     CONDENSEDCONSOLIDATEDBALANCESHEETSUnaudited                   57         │ │
# │ │   BalanceSheetParenthetical        CONDENSEDCONSOLIDATEDBALANCESHEETSUnauditedParenthetical      11         │ │
# │ │   CashFlowStatement                CONDENSEDCONSOLIDATEDSTATEMENTSOFCASHFLOWSUnaudited           36         │ │
# │ │   StatementOfEquity                CONDENSEDCONSOLIDATEDSTATEMENTSOFCHANGESINSTOCKHOLDERSEQUI…   20         │ │
# │ │   StatementOfEquityParenthetical   CONDENSEDCONSOLIDATEDSTATEMENTSOFCHANGESINSTOCKHOLDERSEQUI…   8          │ │
# │ │   AccountingPolicies               CriticalAccountingPolicies                                    2          │ │
# │ │   Other                            RelatedPartyTransactions                                      2          │ │
# │ │   Other                            RevenueRecognition                                            2          │ │
# │ │   SegmentDisclosure                Segments                                                      2          │ │
# │ │   Other                            NetIncomePerShare                                             2          │ │
# │ │   Other                            ShortTermInvestments                                          2          │ │
# │ │   Other                            Inventories                                                   2          │ │
# │ │   Other                            PrepaidExpensesandOtherCurrentAssets                          2          │ │
# │ │   Other                            PropertyPlantandEquipmentNet                                  2          │ │
# │ │   Other                            Leases                                                        3          │ │
# │ │   Other                            DistributionAgreementsNet                                     2          │ │
# │ │   Other                            CustomerListsNet                                              2          │ │
# │ │   Other                            SupplyChainFinanceProgram                                     2          │ │
# │ │   Other                            OtherAccruedLiabilities                                       2          │ │
# │ │   Other                            CommodityDerivativeInstruments                                2          │ │
# │ │   Other                            FairValuesofFinancialInstruments                              2          │ │
# │ │   Other                            IncomeTaxes                                                   2          │ │
# │ │   Other                            PensionandPostretirementBenefitObligations                    2          │ │
# │ │   Other                            OtherLiabilities                                              2          │ │
# │ │   Other                            Debt                                                          2          │ │
# │ │   Other                            CommitmentsandContingencies                                   2          │ │
# │ │   Other                            AccumulatedOtherComprehensiveIncomeLoss                       2          │ │
# │ │   Disclosures                      SupplementalDisclosuresofCashFlowInformation                  2          │ │
# │ │   AccountingPolicies               CriticalAccountingPoliciesPolicies                            4          │ │
# │ │   Other                            RelatedPartyTransactionsTables                                3          │ │
# │ │   Other                            RevenueRecognitionTables                                      3          │ │
# │ │   SegmentDisclosure                SegmentsTables                                                2          │ │
# │ │   Other                            NetIncomePerShareTables                                       2          │ │
# │ │   Other                            ShortTermInvestmentsTables                                    2          │ │
# │ │   Other                            InventoriesTables                                             2          │ │
# │ │   Other                            PrepaidExpensesandOtherCurrentAssetsTables                    2          │ │
# │ │   Other                            PropertyPlantandEquipmentNetTables                            2          │ │
# │ │   Other                            LeasesTables                                                  5          │ │
# │ │   Other                            DistributionAgreementsNetTables                               2          │ │
# │ │   Other                            CustomerListsNetTables                                        2          │ │
# │ │   Other                            OtherAccruedLiabilitiesTables                                 2          │ │
# │ │   Other                            CommodityDerivativeInstrumentsTables                          5          │ │
# │ │   Other                            FairValuesofFinancialInstrumentsTables                        4          │ │
# │ │   Other                            PensionandPostretirementBenefitObligationsTables              2          │ │
# │ │   Other                            OtherLiabilitiesTables                                        2          │ │
# │ │   Other                            DebtTables                                                    2          │ │
# │ │   Other                            CommitmentsandContingenciesTables                             2          │ │
# │ │   Other                            AccumulatedOtherComprehensiveIncomeLossTables                 2          │ │
# │ │   Disclosures                      SupplementalDisclosuresofCashFlowInformationTables            2          │ │
# │ │   AccountingPolicies               CriticalAccountingPoliciesDetails                             10         │ │
# │ │   Other                            RelatedPartyTransactionsNarrativeDetails                      41         │ │
# │ │   Other                            RelatedPartyTransactionsSummaryofSignificantTransactionsbe…   8          │ │
# │ │   Other                            RelatedPartyTransactionsSummaryofLiabilitytoEstimatedFairV…   12         │ │
# │ │   Other                            RevenueRecognitionNarrativeDetails                            26         │ │
# │ │   Other                            RevenueRecognitionSummaryofDisaggregationofRevenuefromCont…   12         │ │
# │ │   Other                            RevenueRecognitionSummaryofActivityforAllowanceforCreditLo…   5          │ │
# │ │   SegmentDisclosure                SegmentsNarrativeDetails                                      7          │ │
# │ │   SegmentDisclosure                SegmentsSummaryofFinancialInformationbySegmentDetails         22         │ │
# │ │   Other                            NetIncomePerShareSummaryofComputationofBasicNetIncomePerSh…   36         │ │
# │ │   Other                            ShortTermInvestmentsSummaryofAvailableforSaleDebtSecuritie…   13         │ │
# │ │   Other                            ShortTermInvestmentsNarrativeDetails                          3          │ │
# │ │   Other                            InventoriesSummaryofInventoriesDetails                        5          │ │
# │ │   Other                            PrepaidExpensesandOtherCurrentAssetsSummaryofPrepaidExpens…   8          │ │
# │ │   Other                            PropertyPlantandEquipmentNetSummaryofPrincipalCategoriesan…   22         │ │
# │ │   Other                            LeasesSummaryofWeightedAverageRemainingLeaseTermandWeighte…   7          │ │
# │ │   Other                            LeasesSummaryofBalancesRelatedtoLeasePortfoliowithinConden…   6          │ │
# │ │   Other                            LeasesSummaryofFutureMinimumLeasePaymentsForNoncancelableO…   25         │ │
# │ │   Other                            LeasesSummaryofFutureMinimumLeasePaymentsForNoncancelableO…   25         │ │
# │ │   Other                            LeasesSummaryofBalancesRelatedtoLeaseswithinCondensedConso…   8          │ │
# │ │   Other                            DistributionAgreementsNetNarrativeDetails                     11         │ │
# │ │   Other                            DistributionAgreementsNetSummaryofDistributionAgreementsNe…   9          │ │
# │ │   Other                            CustomerListsNetNarrativeDetails                              11         │ │
# │ │   Other                            CustomerListsNetSummaryofCustomerListsNetDetails              9          │ │
# │ │   Other                            SupplyChainFinanceProgramDetails                              2          │ │
# │ │   Other                            OtherAccruedLiabilitiesDetails                                9          │ │
# │ │   Other                            CommodityDerivativeInstrumentsSummaryofPretaxChangesinFair…   11         │ │
# │ │   Other                            CommodityDerivativeInstrumentsSummaryofFairValuesandClassi…   11         │ │
# │ │   Other                            CommodityDerivativeInstrumentsSummaryofOutstandingCommodit…   7          │ │
# │ │   Other                            FairValuesofFinancialInstrumentsSummaryofDeferredCompensat…   24         │ │
# │ │   Other                            FairValuesofFinancialInstrumentsNarrativeDetails              17         │ │
# │ │   Other                            FairValuesofFinancialInstrumentsSummaryofAcquisitionRelate…   11         │ │
# │ │   Other                            IncomeTaxesDetails                                            4          │ │
# │ │   Other                            PensionandPostretirementBenefitObligationsSummaryofCompone…   15         │ │
# │ │   Other                            PensionandPostretirementBenefitObligationsNarrativeDetails    13         │ │
# │ │   Other                            PensionandPostretirementBenefitObligationsComponentsofNetP…   10         │ │
# │ │   Other                            OtherLiabilitiesSummaryofOtherLiabilitiesDetails              6          │ │
# │ │   Other                            DebtSummaryofLongtermDebtDetails                              31         │ │
# │ │   Other                            DebtNarrativeDetails                                          4          │ │
# │ │   Other                            CommitmentsandContingenciesNarrativeDetails                   13         │ │
# │ │   Other                            CommitmentsandContingenciesSummaryofCompanysPurchasesfromM…   8          │ │
# │ │   Other                            AccumulatedOtherComprehensiveIncomeLossSummaryofAccumulate…   23         │ │
# │ │   Disclosures                      SupplementalDisclosuresofCashFlowInformationSummaryofChang…   13         │ │
# │ │   Disclosures                      AwardTimingDisclosure                                         20         │ │
# │ │   Disclosures                      ErrCompDisclosure                                             20         │ │
# │ │   Disclosures                      PvpDisclosure                                                 54         │ │
# │ │   Other                            InsiderTradingArrangements                                    18         │ │
# │ │   Other                            InsiderTradingPoliciesProc                                    3          │ │
# │ │                                                                                                             │ │
# │ │      Facts Summary                                                                                          │ │
# │ │                                                                                                             │ │
# │ │   Category      Count                                                                                       │ │
# │ │  ─────────────────────                                                                                      │ │
# │ │   Total Facts   1443                                                                                        │ │
# │ │   Contexts      355                                                                                         │ │
# │ │   Units         8                                                                                           │ │
# │ │   Elements      679                                                                                         │ │
# │ │                                                                                                             │ │
# │ │            Reporting Periods                                                                                │ │
# │ │                                                                                                             │ │
# │ │   Type       Period                                                                                         │ │
# │ │  ─────────────────────────────────────                                                                      │ │
# │ │   Instant    2025-07-18                                                                                     │ │
# │ │   Instant    2025-06-27                                                                                     │ │
# │ │   Duration   2025-01-01 to 2025-06-27                                                                       │ │
# │ │   Duration   2025-03-29 to 2025-06-27                                                                       │ │
# │ │   Duration   2025-05-16 to 2025-05-16                                                                       │ │
# │ │   Instant    2025-03-28                                                                                     │ │
# │ │   Instant    2025-03-04                                                                                     │ │
# │ │   Duration   2025-03-04 to 2025-03-04                                                                       │ │
# │ │   Instant    2024-12-31                                                                                     │ │
# │ │   Duration   2024-01-01 to 2024-12-31                                                                       │ │
# │ │   Instant    2024-08-20                                                                                     │ │
# │ │   Instant    2024-06-28                                                                                     │ │
# │ │   Duration   2024-03-30 to 2024-06-28                                                                       │ │
# │ │   Duration   2024-01-01 to 2024-06-28                                                                       │ │
# │ │   Instant    2024-03-29                                                                                     │ │
# │ │   Instant    2023-12-31                                                                                     │ │
# │ │   Instant    2021-07-09                                                                                     │ │
# │ │                                                                                                             │ │
# │ ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from sec_edgar_downloader import Downloader
dl = Downloader("Giulia", "giuliapetrilli2000@gmail.com")

# %%
dl.get("10-Q", "COKE") # cocacola
# 7minutes
# Out:
# 95

# %%
dl.get("10-Q", "MCD") # McDonald's
# at 71 minutes it was still downloading
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/gpetrilli/Library/CloudStorage/OneDrive-POLITICO/Documents/GitHub/masters_thesis/python_mt/scrape.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/Users/gpetrilli/Library/CloudStorage/OneDrive-POLITICO/Documents/GitHub/masters_thesis/python_mt/scrape.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> dl.get("10-Q", "MCD")
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/sec_edgar_downloader/_Downloader.py:166, in Downloader.get(self, form, ticker_or_cik, limit, after, before, include_amends, download_details, accession_numbers_to_skip)
#     160     form_options = ", ".join(self.supported_forms)
#     161     raise ValueError(
#     162         f"{form!r} forms are not supported. "
#     163         f"Please choose from the following: {form_options}."
#     164     )
# --> 166 num_downloaded = fetch_and_save_filings(
#     167     DownloadMetadata(
#     168         self.download_folder,
#     169         form,
#     170         cik,
#     171         limit,
#     172         after_date,
#     173         before_date,
#     174         include_amends,
#     175         download_details,
#     176         # Save ticker if passed in to form file system path for saving filings
#     177         ticker=ticker_or_cik if not is_cik(ticker_or_cik) else None,
#     178         accession_numbers_to_skip=accession_numbers_to_skip,
#     179     ),
#     180     self.user_agent,
#     181 )
#     183 return num_downloaded
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/sec_edgar_downloader/_orchestrator.py:146, in fetch_and_save_filings(download_metadata, user_agent)
#     142 save_location = get_save_location(
#     143     download_metadata, td.accession_number, FILING_FULL_SUBMISSION_FILENAME
#     144 )
#     145 if not save_location.exists():
# --> 146     raw_filing = download_filing(td.raw_filing_uri, user_agent)
#     147     save_document(raw_filing, save_location)
#     149 if download_metadata.download_details:
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/sec_edgar_downloader/_sec_gateway.py:45, in download_filing(uri, user_agent)
#      44 def download_filing(uri: str, user_agent: str) -> bytes:
# ---> 45     return _call_sec(uri, user_agent, HOST_WWW_SEC).content
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pyrate_limiter/limiter.py:463, in Limiter.as_decorator.<locals>.with_mapping_func.<locals>.decorator_wrapper.<locals>.wrapper(*args, **kwargs)
#     460 accquire_ok = self.try_acquire(name, weight)
#     462 if not isawaitable(accquire_ok):
# --> 463     return func(*args, **kwargs)
#     465 async def _handle_accquire_async():
#     466     nonlocal accquire_ok
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/sec_edgar_downloader/_sec_gateway.py:32, in _call_sec(uri, user_agent, host)
#      30 @limiter(limiter_mapping)
#      31 def _call_sec(uri: str, user_agent: str, host: str) -> Response:
# ---> 32     resp = requests.get(
#      33         uri,
#      34         headers={
#      35             **STANDARD_HEADERS,
#      36             "User-Agent": user_agent,
#      37             "Host": host,
#      38         },
#      39     )
#      40     resp.raise_for_status()
#      41     return resp
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/urllib3/response.py:1091, in HTTPResponse.stream(self, amt, decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1091         data = self.read(amt=amt, decode_content=decode_content)
#    1093         if data:
#    1094             yield data
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/urllib3/response.py:980, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     977     if len(self._decoded_buffer) >= amt:
#     978         return self._decoded_buffer.get(amt)
# --> 980 data = self._raw_read(amt)
#     982 flush_decoder = amt is None or (amt != 0 and not data)
#     984 if not data and len(self._decoded_buffer) == 0:
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/urllib3/response.py:904, in HTTPResponse._raw_read(self, amt, read1)
#     901 fp_closed = getattr(self._fp, "closed", False)
#     903 with self._error_catcher():
# --> 904     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     905     if amt is not None and amt != 0 and not data:
#     906         # Platform-specific: Buggy versions of Python.
#     907         # Close the connection when no data is returned
#    (...)
#     912         # not properly close the connection in all cases. There is
#     913         # no harm in redundantly calling close.
#     914         self._fp.close()
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/urllib3/response.py:887, in HTTPResponse._fp_read(self, amt, read1)
#     884     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     885 else:
#     886     # StringIO doesn't like amt=None
# --> 887     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/miniconda3/envs/myenv/lib/python3.11/http/client.py:473, in HTTPResponse.read(self, amt)
#     470 if self.length is not None and amt > self.length:
#     471     # clip the read to the "end of response"
#     472     amt = self.length
# --> 473 s = self.fp.read(amt)
#     474 if not s and amt:
#     475     # Ideally, we would raise IncompleteRead if the content-length
#     476     # wasn't satisfied, but it might break compatibility.
#     477     self._close_conn()
#
# File ~/miniconda3/envs/myenv/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/miniconda3/envs/myenv/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
dl.get("10-Q", "QSR") # Restaurant Brands International (Burger King, Tim Hortons, Popeyes)
#haven't started yet
